# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
#adapt folder path
data_folder = './Data/'

#Beer Advocate:
path_ba = data_folder + 'BeerAdvocate/'
#corresponds to a smaller version of reviews.txt
path_ba_reviews = data_folder + "reviews_small.txt"

#matched:
path_ma = data_folder + 'matched_beer_data/'

# %%
#get reviews text data (warning, big file)
def parsing(path):
    with open(path, "r", encoding='utf-8') as file:
        beer = {}
        review_list = []
        for line in file:
            if line.isspace():
                review_list.append(beer)
                beer = {}
            else:
                beer[line.split()[0][:-1]] =" ".join(line.split()[1:])
    df = pd.DataFrame(review_list)
    
    #making dataframe
    for col in ["beer_id", "brewery_id", "appearance", "aroma", "palate", "taste", "overall", "rating", "abv"]:
        df[col] = pd.to_numeric(df[col], errors = 'ignore')
    df["date"] = pd.to_datetime(df["date"],unit='s')
    df.set_index(df["date"], inplace = True)
    
    return df

# %%
review_ba_ma = parsing(path_ma + "ratings_with_text_ba.txt")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-9-6fec5fa43b50> in <module>
# ----> 1 review_ba_ma = parsing(path_ma + "ratings_with_text_ba.txt")
#
# <ipython-input-8-a739c1a5774f> in parsing(path)
#       1 #get reviews text data (warning, big file)
#       2 def parsing(path):
# ----> 3     with open(path, "r", encoding='utf-8') as file:
#       4         beer = {}
#       5         review_list = []
#
# FileNotFoundError: [Errno 2] No such file or directory: './Data/matched_beer_data/ratings_with_text_ba.txt'

# %%
review_ba_ma
# Out:
#                                   beer_name  beer_id  \
# date
# 2013-02-13 11:00:00                Legbiter    19827
# 2013-01-09 11:00:00                Legbiter    19827
# 2012-11-17 11:00:00                Legbiter    19827
# 2012-07-14 10:00:00                Legbiter    19827
# 2012-04-28 10:00:00                Legbiter    19827
# ...                                     ...      ...
# 2011-09-29 10:00:00             Lazy Saison    72174
# 2014-01-27 11:00:00  Night Before Christmas    77388
# 2013-01-28 11:00:00  Night Before Christmas    77388
# 2013-01-08 11:00:00  Night Before Christmas    77388
# 2012-01-14 11:00:00  Night Before Christmas    77388
#
#                                              brewery_name  brewery_id  \
# date
# 2013-02-13 11:00:00  Strangford Lough Brewing Company Ltd       10093
# 2013-01-09 11:00:00  Strangford Lough Brewing Company Ltd       10093
# 2012-11-17 11:00:00  Strangford Lough Brewing Company Ltd       10093
# ...

# %%
review_ba_ma.to_pickle(data_folder + "/matched_beer_data/ratings_with_text_ba")
